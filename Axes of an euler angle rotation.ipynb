# %% [markdown]
# （書きかけ）

# %%
using Plots
pyplot(
    legend=false,
    xlims=(-1.0,1.0), ylims=(-1.0,1.0), zlims=(-1.0,1.0),
    ticks=nothing
)
function plot_axes(cmrx, cmry, ttl)
    p = plot([0,0], [0,0], [0,1],
             color=:blue, lw=3, camera=(cmrx,cmry))
    for θ = π/16:π/16:2π
        rx = -1 + cos(θ) - sin(θ)
        ry = -1 - cos(θ) + sin(θ)
        rz =  1 - cos(θ) - sin(θ)
        r = √(rx^2 + ry^2 + rz^2)
        plot!(p, [0.0,rx/r], [0.0,rz/r], [0.0,-ry/r],
              color=:blue, lw=ifelse(θ<π/2,3,1), camera=(cmrx,cmry))
    end
    plot!(p, θ->-sin(θ), θ->-cos(θ), θ->0, 0, 2π,
          camera=(cmrx,cmry), title=ttl, line=:dot, color=:black)
    plot!(p, θ->-sin(θ), θ->0, θ->-cos(θ), 0, 2π,
          camera=(cmrx,cmry), title=ttl, line=:dot, color=:black)
    plot!(p, θ->0, θ->-sin(θ), θ->-cos(θ), 0, 2π,
          camera=(cmrx,cmry), title=ttl, line=:dot, color=:black)
end
pxy = plot_axes(0, 0, "front view")
pzy = plot_axes(-90, 0, "left side view")
plot(pzy, pxy, layout=2, size=(1000,500))
# Out:
# <img src="data:image/png;base64,..." />

# %%
using Plots
pyplot(
    xlims=(0.0,2π),ylims=(0.0,3π/2),
    xlab="θ",ylab="rotation angle",
    ticks=0:π/4:2π,
    size=(577,433),
    legend=false
)
f(θ) = 2acos((1+cos(θ)+sin(θ))/(2*√2))
plot(f, 0.0, 2π, color=:red, lw=1)
plot!(f, 0.0, π/2, color=:red, lw=3)
# Out:
# <img src="data:image/png;base64,..." />
